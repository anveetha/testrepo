# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Peer-graded Assignment: Jupyter Notebooks

# %% [markdown]
# Hello! My name is Anveetha, and I am working to complete the IBM Data Science Career Certification.

# %% [markdown]
# 1. Python
# 2. Java
# 3. R
# 4. C++
# 5. SQL
# 6. JavaScript
# 7. Scala
# 8. MATLAB

# %% [markdown]
# 1. Scikit-learn
# 2. Matplotlib
# 3. Pandas
# 4. NumPy
# 5. SciPy

# %% [markdown]
# | Data Science Tools |
# |-------------------|
# | R & RStudio |
# | Github |
# | Jupyter Notebooks |
# | APIs |

# %% [markdown]
# ### Arithmetic Expression Examples:
# Arithmetic expressions can be very different from one another, and they only include + , * , and - as operators. <br>
# Some examples are:  <br>
# 5  <br>
# (3 + 4)  <br>
# (6 - 2) * 3  <br>
# 4 * 2  <br>

# %%
(3 + 4) * 2
# Out:
# 14

# %%
# to convert minutes to hours, you must divide the number of minutes by 60. 
# I will use an arbitrary number for minutes
mins = 225
hours = mins/60
print(hours)
# Out:
# 3.75

# %% [markdown]
# ### Objectives
# * Create a Jupyter Notebook
# * Insert code and markdown cells
# * Share your notebook through GitHub

# %% [markdown]
# ### Author
# Anveetha S.
